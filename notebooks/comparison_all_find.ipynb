# %%
import os

print(os.getcwd())
import os

for root, dirs, files in os.walk("."):

    level = root.replace(".", "").count(os.sep)

    if level > 2:
        continue

    indent = "    " * level

    print(f"{indent}{os.path.basename(root)}/")

    for file in sorted(files):

        print(f"{indent}    {file}")

import os

for root, dirs, files in os.walk("."):

    for file in sorted(files):

        path = os.path.join(root, file)

        size = os.path.getsize(path) / 1024

        print(

            f"{path:70} {size:10.2f} KB"

        )

import os

extensions = (

    ".pt",

    ".pth",

    ".ckpt"

)

for root, dirs, files in os.walk("."):

    for file in files:

        if file.endswith(extensions):

            print(

                os.path.join(root, file)

            )

import os

for root, dirs, files in os.walk("."):

    for file in files:

        if file.endswith(".csv"):

            print(

                os.path.join(root, file)

            )
# Out:
# C:\Users\HP\Documents\python\bio informatics\final exam\ThreatGraphx\notebooks
# ./
#     01_Data_Inspection.ipynb
#     02_CVE_Extraction.ipynb
#     03_CWE_Extraction.ipynb
#     04_CVE_CWE_Edges.ipynb
#     05_CAPEC_Extraction.ipynb
#     06_CWE_CAPEC_Edges.ipynb
#     07_ATTACK_Extraction.ipynb
#     08_ATTACK_Mitigations.ipynb
#     09_Software_Extraction.ipynb
#     10_Graph_Construction.ipynb
#     11_Graph_Visualization.ipynb
#     12_Data_Split.ipynb
#     13_Create_Triples.ipynb
#     14_TransE_Baseline.ipynb
#     15_DistMult_Baseline.ipynb
#     16_Create_Graph_Tensors.ipynb
#     17_GraphSAGE.ipynb
#     18_RGCN.ipynb
#     19_ThreatGraphX_Tx.ipynb
#     20_Strict_Zero_Shot_Evaluation.ipynb
#     21_CyberTxGNN.ipynb
#     22_CyberTxGNN.ipynb
#     22_CyberTxGNN_Enhanced.ipynb
#     22_CyberTxGNN_Enhanced2222.ipynb
#     22_CyberTxGNN_Enhanced333333.ipynb
#     22_CyberTxGNN_Enhanced4444444.ipynb
#     comparison_all_find.ipynb
#     .ipynb_checkpoints/
# ...

# %%
import os

for root, dirs, files in os.walk("."):

    for file in files:

        if file.endswith(".csv"):

            print(

                os.path.join(root, file)

            )

# %%
import os

extensions = (

    ".pkl",

    ".pickle",

    ".joblib"

)

for root, dirs, files in os.walk("."):

    for file in files:

        if file.endswith(extensions):

            print(

                os.path.join(root, file)

            )

# %%
import os

extensions = (

    ".png",

    ".jpg",

    ".jpeg",

    ".svg",

    ".pdf"

)

for root, dirs, files in os.walk("."):

    for file in files:

        if file.endswith(extensions):

            print(

                os.path.join(root, file)

            )

# %%
import os

import torch

import pandas as pd

import numpy as np

from IPython.display import display

print("Current Folder:")

print(os.getcwd())
# Out:
# Current Folder:
# C:\Users\HP\Documents\python\bio informatics\final exam\ThreatGraphx\notebooks

# %%
import glob

notebooks = sorted(

    glob.glob(

        "*.ipynb"

    )

)

print(

    f"Total Notebooks : {len(notebooks)}"

)

for notebook in notebooks:

    print(

        notebook

    )
# Out:
# Total Notebooks : 27
# 01_Data_Inspection.ipynb
# 02_CVE_Extraction.ipynb
# 03_CWE_Extraction.ipynb
# 04_CVE_CWE_Edges.ipynb
# 05_CAPEC_Extraction.ipynb
# 06_CWE_CAPEC_Edges.ipynb
# 07_ATTACK_Extraction.ipynb
# 08_ATTACK_Mitigations.ipynb
# 09_Software_Extraction.ipynb
# 10_Graph_Construction.ipynb
# 11_Graph_Visualization.ipynb
# 12_Data_Split.ipynb
# 13_Create_Triples.ipynb
# 14_TransE_Baseline.ipynb
# 15_DistMult_Baseline.ipynb
# 16_Create_Graph_Tensors.ipynb
# 17_GraphSAGE.ipynb
# 18_RGCN.ipynb
# 19_ThreatGraphX_Tx.ipynb
# 20_Strict_Zero_Shot_Evaluation.ipynb
# 21_CyberTxGNN.ipynb
# 22_CyberTxGNN.ipynb
# 22_CyberTxGNN_Enhanced.ipynb
# 22_CyberTxGNN_Enhanced2222.ipynb
# 22_CyberTxGNN_Enhanced333333.ipynb
# 22_CyberTxGNN_Enhanced4444444.ipynb
# comparison_all_find.ipynb

# %%
from pathlib import Path

project = Path.cwd().parent

print(project)

print()

for folder in sorted(project.iterdir()):

    print(folder.name)
# Out:
# C:\Users\HP\Documents\python\bio informatics\final exam\ThreatGraphx
#
# data
# docs
# models
# notebooks
# outputs
# results
# src

# %%
from pathlib import Path

project_root = Path.cwd().parent

data_folder = project_root / "data"

print(data_folder)

print()

for file in sorted(data_folder.rglob("*")):

    if file.is_file():

        print(

            file.relative_to(project_root)

        )
# Out:
# C:\Users\HP\Documents\python\bio informatics\final exam\ThreatGraphx\data
#
# data\ml_ready\edge_index.npy
# data\ml_ready\edge_type.npy
# data\ml_ready\node2id.pkl
# data\ml_ready\relation2id.pkl
# data\processed\attack_mitigation_edges.csv
# data\processed\capec_attack_edges.csv
# data\processed\capec_nodes.csv
# data\processed\cve_cwe_edges.csv
# data\processed\cve_nodes.csv
# data\processed\cwe_capec_edges.csv
# data\processed\cwe_nodes.csv
# data\processed\software_edges.csv
# data\raw\attack\enterprise-attack-19.1.json
# data\raw\capec\capec_latest.xml
# data\raw\cve\nvdcve-2.0-modified.json
# data\raw\cve\nvdcve-2.0-recent.json
# data\raw\cwe\1435.xml
# data\splits\test_edges.csv
# data\splits\train_edges.csv
# data\splits\val_edges.csv
# data\triples\test_triples.csv
# data\triples\train_triples.csv
# data\triples\val_triples.csv

# %%
models_folder = project_root / "models"

print(models_folder)

print()

for file in sorted(models_folder.rglob("*")):

    if file.is_file():

        print(

            file.relative_to(project_root)

        )
# Out:
# C:\Users\HP\Documents\python\bio informatics\final exam\ThreatGraphx\models
#
# models\DistMult\metadata.json
# models\DistMult\results.json
# models\DistMult\trained_model.pkl
# models\DistMult\training_triples\base.pth
# models\DistMult\training_triples\entity_to_id.tsv.gz
# models\DistMult\training_triples\numeric_triples.tsv.gz
# models\DistMult\training_triples\relation_to_id.tsv.gz
# models\graphsage_model.pth
# models\graphsage_predictor.pth
# models\relation2id.pkl
# models\rgcn_complete_checkpoint.pt
# models\rgcn_model.pth
# models\rgcn_node_embeddings.pt
# models\rgcn_predictor.pth
# models\TransE\metadata.json
# models\TransE\results.json
# models\TransE\trained_model.pkl
# models\TransE\training_triples\base.pth
# models\TransE\training_triples\entity_to_id.tsv.gz
# models\TransE\training_triples\numeric_triples.tsv.gz
# models\TransE\training_triples\relation_to_id.tsv.gz
# models\tx_predictor.pth

# %%
outputs_folder = project_root / "outputs"

print(outputs_folder)

print()

for file in sorted(outputs_folder.rglob("*")):

    if file.is_file():

        print(

            file.relative_to(project_root)

        )
# Out:
# C:\Users\HP\Documents\python\bio informatics\final exam\ThreatGraphx\outputs

# %%
results_folder = project_root / "results"

print(results_folder)

print()

for file in sorted(results_folder.rglob("*")):

    if file.is_file():

        print(

            file.relative_to(project_root)

        )
# Out:
# C:\Users\HP\Documents\python\bio informatics\final exam\ThreatGraphx\results
#
# results\explainable_path_example.csv
# results\model_comparison.csv
# results\rgcn_threat_discovery.csv
# results\strict_zero_shot_comparison.csv

# %%
src_folder = project_root / "src"

print(src_folder)

print()

for file in sorted(src_folder.rglob("*")):

    if file.is_file():

        print(

            file.relative_to(project_root)

        )
# Out:
# C:\Users\HP\Documents\python\bio informatics\final exam\ThreatGraphx\src
